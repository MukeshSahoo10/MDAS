# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.28.2-py2.py3-none-any.whl (8.4 MB)
#      ---------------------------------------- 8.4/8.4 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.27 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 2.0 MB/s eta 0:00:00
# Collecting tenacity<9,>=8.1.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Collecting pyarrow>=6.0
#   Downloading pyarrow-14.0.1-cp310-cp310-win_amd64.whl (24.6 MB)
#      ---------------------------------------- 24.6/24.6 MB 2.7 MB/s eta 0:00:00
# Collecting validators<1,>=0.2
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Collecting altair<6,>=4.0
#   Downloading altair-5.1.2-py3-none-any.whl (516 kB)
#      -------------------------------------- 516.2/516.2 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Collecting tzlocal<6,>=1.1
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (4.24.2)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (22.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      -------------------------------------- 190.6/190.6 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\asims\anaconda3\lib\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\asims\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\asims\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: jinja2 in c:\users\asims\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: colorama in c:\users\asims\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\asims\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asims\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\asims\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asims\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asims\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\asims\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asims\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2022.12.7)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asims\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asims\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Collecting tzdata
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asims\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\asims\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\asims\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asims\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Installing collected packages: validators, tzdata, tenacity, smmap, pyarrow, blinker, tzlocal, pydeck, gitdb, gitpython, altair, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
# Successfully installed altair-5.1.2 blinker-1.7.0 gitdb-4.0.11 gitpython-3.1.40 pyarrow-14.0.1 pydeck-0.8.1b0 smmap-5.0.1 streamlit-1.28.2 tenacity-8.2.3 tzdata-2023.3 tzlocal-5.2 validators-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
import streamlit as st

file_name = "finalized_model.sav"
loaded_model = joblib.load(file_name)

st.title("Suicide Analysis")
# st.header("Suicide Analysis")

st.markdown("Enter text below to see whether the text you have entered is suicidal or not.")

# removing the streamlit banner at the bottom
hide_streamlit_style = """
            <style>
            footer {visibility: hidden;}
            </style>
            """
st.markdown(hide_streamlit_style, unsafe_allow_html=True)

st.text_input("Text", key="user_text")

# You can access the value at any point with:
text = st.session_state.user_text
print(text)

result = loaded_model.predict([text])

st.write(result[0])

# Run `python -m streamlit run stream.py`
# to run the file
# Out:
# C:\Users\asims\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.24.1 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\asims\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.24.1 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\asims\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator SGDClassifier from version 0.24.1 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\asims\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator Pipeline from version 0.24.1 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2023-11-16 12:13:56.818
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\asims\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2023-11-16 12:13:56.820 Session state does not function when running a script without `streamlit run`
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:394, in SessionState.__getitem__(self, key)
#     393 try:
# --> 394     return self._getitem(widget_id, key)
#     395 except KeyError:
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:439, in SessionState._getitem(self, widget_id, user_key)
#     438 # We'll never get here
# --> 439 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:119, in SessionStateProxy.__getattr__(self, key)
#     118 try:
# --> 119     return self[key]
#     120 except KeyError:
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:90, in SessionStateProxy.__getitem__(self, key)
#      89 require_valid_user_key(key)
# ---> 90 return get_session_state()[key]
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\safe_session_state.py:89, in SafeSessionState.__getitem__(self, key)
#      88 with self._lock:
# ---> 89     return self._state[key]
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:396, in SessionState.__getitem__(self, key)
#     395 except KeyError:
# --> 396     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "user_text". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 23
#      20 st.text_input("Text", key="user_text")
#      22 # You can access the value at any point with:
# ---> 23 text = st.session_state.user_text
#      24 print(text)
#      26 result = loaded_model.predict([text])
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:121, in SessionStateProxy.__getattr__(self, key)
#     119     return self[key]
#     120 except KeyError:
# --> 121     raise AttributeError(_missing_attr_error_message(key))
#
# AttributeError: st.session_state has no attribute "user_text". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization
